# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pivot Table

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}
df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    322     54   John  January      Q1
# 1  2023-01-02       B   West    842     40   Mary  January      Q1
# 2  2023-01-03       C  North    961     58    Bob  January      Q1
# 3  2023-01-04       D  South    592     98  Alice  January      Q1
# 4  2023-01-05       A   East    756     99   John  January      Q1
# 5  2023-01-06       B   West    725     42   Mary  January      Q1
# 6  2023-01-07       C  North    502     50    Bob  January      Q1
# 7  2023-01-08       D  South    330     65  Alice  January      Q1
# 8  2023-01-09       A   East    215     89   John  January      Q1
# 9  2023-01-10       B   West    540     21   Mary  January      Q1
# 10 2023-01-11       C  North    195     15    Bob  January      Q1
# 11 2023-01-12       D  South    699     77  Alice  January      Q1
# 12 2023-01-13       A   East    825     73   John  January      Q1
# 13 2023-01-14       B   West    657     97   Mary  January      Q1
# 14 2023-01-15       C  North    646     32    Bob  January      Q1
# 15 2023-01-16       D  South    928     11  Alice  January      Q1
# 16 2023-01-17       A   East    656     60   John  January      Q1
# 17 2023-01-18       B   West    643     50   Mary  January      Q1
# 18 2023-01-19       C  North    380     87    Bob  January      Q1
# 19 2023-01-20       D  South    155     67  Alice  January      Q1

# %%
# Create a pivot table showing Sales grouped by Region (rows) and Product (columns), default aggregation = mean
pd.pivot_table(df,values="Sales",index="Region",columns="Product")
# Out:
# Product      A      B      C      D
# Region
# East     554.8    NaN    NaN    NaN
# North      NaN    NaN  536.8    NaN
# South      NaN    NaN    NaN  540.8
# West       NaN  681.4    NaN    NaN

# %%
pd.pivot_table(df,values=["Sales","Units"],index="Region",columns="Product")
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     554.8    NaN    NaN    NaN  75.0   NaN   NaN   NaN
# North      NaN    NaN  536.8    NaN   NaN   NaN  48.4   NaN
# South      NaN    NaN    NaN  540.8   NaN   NaN   NaN  63.6
# West       NaN  681.4    NaN    NaN   NaN  50.0   NaN   NaN

# %% [markdown]
# CrossTabs

# %%
pd.crosstab(df["Region"],df["Product"])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
